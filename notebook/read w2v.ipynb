# %%
import pickle

# %%
with open('../data/fast_text_vectors_wiki.en.vec/wiki.en.vec','r') as f:
    a =f.readlines()

# %%
vocab_size,embed_size = map(int,a[0].split())

# %%
embed_size
# Out:
# 300

# %%
vocab = {}
for line in a[1:]:
    line_split = line.split()
    vocab[line_split[0]] = map(float,line_split[1:])

# %%
vocab['during']
# Out:
# [-0.0028316,
#  -0.11639,
#  0.034826,
#  0.10182,
#  -0.23719,
#  -0.13836,
#  0.017394,
#  -0.04959,
#  0.15117,
#  0.10769,
#  0.15469,
#  0.13231,
#  -0.050474,
#  0.013186,
#  -0.10079,
#  -0.041895,
#  -0.14529,
#  -0.09169,
#  -0.12864,
#  0.34336,
#  -0.041634,
#  0.11426,
#  -0.30599,
#  -0.23712,
#  0.013253,
#  -0.22438,
#  -0.059319,
#  -0.021036,
#  -0.16955,
#  -0.018966,
#  -0.22345,
#  -0.027041,
#  -0.098154,
#  0.1915,
#  0.41692,
#  -0.051896,
#  0.062081,
#  -0.022674,
#  0.14239,
#  -0.18741,
#  0.068541,
#  0.021078,
#  -0.179,
#  -0.11551,
#  -0.12505,
#  -0.32687,
#  -0.10169,
#  0.20185,
#  0.24937,
#  0.13857,
#  0.23329,
#  0.046257,
#  -0.028843,
#  0.14632,
#  -0.0054476,
#  0.067744,
#  0.04093,
#  0.14329,
#  -0.17303,
#  0.074436,
#  -0.0062461,
#  -0.2196,
#  0.15326,
#  -0.065867,
#  0.11974,
#  -0.15327,
#  -0.22104,
#  0.26262,
#  -0.17585,
#  -0.083629,
#  -0.23718,
#  -0.10308,
#  -0.21428,
#  -0.024736,
#  0.14132,
#  0.034751,
#  0.3765,
# ...

# %%
a[100].split()
# Out:
# ['during',
#  '-0.0028316',
#  '-0.11639',
#  '0.034826',
#  '0.10182',
#  '-0.23719',
#  '-0.13836',
#  '0.017394',
#  '-0.04959',
#  '0.15117',
#  '0.10769',
#  '0.15469',
#  '0.13231',
#  '-0.050474',
#  '0.013186',
#  '-0.10079',
#  '-0.041895',
#  '-0.14529',
#  '-0.09169',
#  '-0.12864',
#  '0.34336',
#  '-0.041634',
#  '0.11426',
#  '-0.30599',
#  '-0.23712',
#  '0.013253',
#  '-0.22438',
#  '-0.059319',
#  '-0.021036',
#  '-0.16955',
#  '-0.018966',
#  '-0.22345',
#  '-0.027041',
#  '-0.098154',
#  '0.1915',
#  '0.41692',
#  '-0.051896',
#  '0.062081',
#  '-0.022674',
#  '0.14239',
#  '-0.18741',
#  '0.068541',
#  '0.021078',
#  '-0.179',
#  '-0.11551',
#  '-0.12505',
#  '-0.32687',
#  '-0.10169',
#  '0.20185',
#  '0.24937',
#  '0.13857',
#  '0.23329',
#  '0.046257',
#  '-0.028843',
#  '0.14632',
#  '-0.0054476',
#  '0.067744',
#  '0.04093',
#  '0.14329',
#  '-0.17303',
#  '0.074436',
#  '-0.0062461',
#  '-0.2196',
#  '0.15326',
#  '-0.065867',
#  '0.11974',
#  '-0.15327',
# ...
