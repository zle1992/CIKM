# %%
import pandas as pd

# %%
df1 = pd.read_table('../data/origin_data/cikm_english_train_20180516.txt',names=['q1','q1_trans','q2','q2_trans','label'])

# %%
df1.q1.map(lambda x:x.split())
# Out:
# 0                [hello,, i, click, in, product, received]
# 1        [Hello!, I, have, closed, the, dispute, on, ma...
# 2        [l, ordered, from, spain, to, spain, now, they...
# 3                     [Do, I, need, to, pay, custom, duty]
# 4                         [I, didn't, receive, my, order?]
# 5        [Hi, Eva., At, first, the, question., Can, I, ...
# 6                                       [I, am, so, angry]
# 7                    [I, am, not, able, to, open, dispute]
# 8                     [how, can, I, check, order, number?]
# 9                   [No,, I, need, an, answer, from, you.]
# 10                           [how, to, reply, to, dispute]
# 11       [I, DONT, NOT, LIVE, IN, CHINA,, I, LIVE, BRAZIL]
# 12       [What, does, it, mean:, Your, order, will, be,...
# 13                              [how, to, exchange, coins]
# 14                  [how, do, I, report, a, fraud, seller]
# 15       [Hi, I, want, to, buy, something, but, seller,...
# ...

# %%
df2 = pd.read_table('../data/cikm_spanish_train_20180516.txt',names=['q1','q1_trans','q2','q2_trans','label'])

# %%
df2
# Out:
#                                                      q1  \
# 0     ?No he podido pagar con mi tarjeta, que debo h...
# 1     ?Por qué aparece "no pagado" cuando el pago ya...
# 2     ?Cuándo recibiré mi reembolso si pago con tarj...
# 3             ?Qué pasará después de abrir una disputa?
# 4     El producto que he recibido no corresponde con...
# 5                     ?Por qué se ha cerrado mi pedido?
# 6                 ?Por qué no puedo realizar un pedido?
# 7       ?Por qué mi pago está deducido incorrectamente?
# 8     ?Como puedo pagar con mi tarjeta de credito/de...
# 9     ?Por qué mi pedido está en verificación tras e...
# 10    ?Cómo puedo recibir un reembolso con la tarjet...
# 11    ?Cómo puedo recibir un reembolso con la tarjet...
# 12    ?Cómo puedo recibir un reembolso con la tarjet...
# 13             ?Como puedo pagar mediante Mercado Pago?
# 14    El producto recibido no es bueno, no funciona,...
# 15    ?Puedo cambiar los detalles del pedido (tamaño...
# ...

# %%
df3 = pd.read_table('../data/cikm_test_a_20180516.txt',names=['q1','q1_trans','q2','q2_trans','label'])

# %%
df3
# Out:
#                                                      q1  \
# 0     ?Cómo puedo recibir un reembolso mediante tarj...
# 1     ?Cómo puedo recibir un reembolso mediante tarj...
# 2     ?No he podido pagar con mi tarjeta, que debo h...
# 3     ?No he podido pagar con mi tarjeta, que debo h...
# 4     ?No he podido pagar con mi tarjeta, que debo h...
# 5     ?Por qué no se ha podido procesar mi pago por ...
# 6     ?Cuándo recibiré mi reembolso si pago con tarj...
# 7             ?Qué pasará después de abrir una disputa?
# 8             ?Qué pasará después de abrir una disputa?
# 9     ?Por qué ha sido finalizado mi pedido por razo...
# 10    El producto que he recibido no corresponde con...
# 11                    ?Por qué se ha cerrado mi pedido?
# 12                    ?Por qué se ha cerrado mi pedido?
# 13                    ?Por qué se ha cerrado mi pedido?
# 14                    ?Por qué se ha cerrado mi pedido?
# 15     ?Cómo utilizo el Servicio de Garantía de un Año?
# ...

# %%
df4 = pd.read_table('../data/cikm_unlabel_spanish_train_20180516.txt',names=['q1','q1_trans','q2','q2_trans','label'])

# %%
df4
# Out:
#                                                       q1  \
# 0      Por qué no se ha podido procesar mi pago por r...
# 1      tengo una duda Tengo una pregunta sobre mis cu...
# 2      Por favor necesito saber si mi compra todavía ...
# 3      Cómo cancelo un pedido Si cancelo el pedido re...
# 4      Cómo puedo recibir un reembolso mediante tarje...
# 5      Confirmar la recepción del pedido He confirmad...
# 6      Cómo buscar con la identificación del producto...
# 7      Cómo pagar con tarjeta de débito Puedo pagar c...
# 8      Por qué mi pago está deducido incorrectamente ...
# 9      Depósito bancario Cómo recibo mi justificante ...
# 10     Por qué mi pago está deducido incorrectamente ...
# 11     No puedo realizar pagos Por qué me cobraron do...
# 12     Cómo utilizo el Servicio de Garantía de un Año...
# 13     que significa confirmación caducada Qué signif...
# 14     Cómo puedo recibir un reembolso mediante tarje...
# ...
